# %% [markdown]
# <style>
#   .laporan-container {
#     font-family: "Times New Roman", Times, serif !important;
#     line-height: 1.5; /* Ditingkatkan sedikit agar lebih enak dibaca */
#     display: flex;
#     flex-direction: column;
#     align-items: center; /* Memaksa elemen flex ke tengah horizontal */
#     text-align: center;
#     width: 100%;
#     margin: 0 auto;
#   }
#
#   /* Memastikan gambar selalu di tengah */
#   .laporan-container img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
#   }
#
#   /* Menghapus margin default judul agar jaraknya pas */
#   .laporan-container h1, .laporan-container h2, .laporan-container h3 {
#     margin: 10px 0;
#   }
# </style>
#
# <div class="laporan-container">
#
# # **TUGAS FISIKA KOMPUTASI**
# ## **Astrophysical Time Series - Solar Cycle Analysis**
#
# <br>
#
# <img src="logo_itk_baru.jpg" width="300" alt="Logo ITK">
#
# <br>
#
# **Disusun Oleh:**
# <br>
# Loza Asmi Nahara Maharani (01241011)
# <br>
# Putri Herawati (01241018)
#
# <br>
#
# **Dosen Pengampu:**
# Agus Rifani, S.Si, M.Si.
#
# <br>
# <br>
#
# ### **JURUSAN SAINS DAN ANALITIKA DATA**
# ### **INSTITUT TEKNOLOGI KALIMANTAN**
# ### **2026**
#
# </div>
